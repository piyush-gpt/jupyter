# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 825.8 kB/s eta 0:00:47
#    ---------------------------------------- 0.4/38.6 MB 3.2 MB/s eta 0:00:12
#     --------------------------------------- 0.7/38.6 MB 5.3 MB/s eta 0:00:08
#    - -------------------------------------- 1.5/38.6 MB 8.2 MB/s eta 0:00:05
#    -- ------------------------------------- 2.3/38.6 MB 9.6 MB/s eta 0:00:04
#    --- ------------------------------------ 2.9/38.6 MB 10.4 MB/s eta 0:00:04
#    --- ------------------------------------ 3.3/38.6 MB 9.6 MB/s eta 0:00:04
#    --- ------------------------------------ 3.6/38.6 MB 9.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.3/38.6 MB 9.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/38.6 MB 9.9 MB/s eta 0:00:04
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
opencv=cv2.imread("C:\\Users\\lenovo\\Downloads\\openCVtest.jpeg") # gives bgr image
plt.imshow(opencv) # here bgr image is getting converted to rgb , shuffing is not taking place ,bgr is directly assigned the value as that to rgb

# %%
opencv2=cv2.cvtColor(opencv, cv2.COLOR_BGR2RGB) # here proper shuffling of array [0] (B) arr[1] (G) arr[2] (R) is taking place 
# now in new array arr[0] becomes arr[2] of previous array and so on
plt.imshow(opencv2)

# %%
import cv2

S = 0

source = cv2. VideoCapture(s)
win_name = 'Camera Preview'
cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)
while cv2.waitKey(1) != 27: # Escape
    has_frame, frame = source.read()
    if not has_frame:
        break
    frame=cv2.flip(frame,1)   
    cv2.imshow(win_name, frame)
source.release()
cv2.destroyWindow(win_name)

# %%
S = 0

source = cv2. VideoCapture(s)
win_name = 'Camera Preview'
cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)
while cv2.waitKey(1) != 27: # Escape
    has_frame, frame = source.read()
    if not has_frame:
        break
    frame=cv2.flip(frame,1) 
    frame=cv2.Canny(frame,100,120,3)
    cv2.imshow(win_name, frame)
source.release()
cv2.destroyWindow(win_name)

# %%
S = 0
import numpy as np
source = cv2. VideoCapture(s)
win_name = 'Camera Preview'
cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)
while cv2.waitKey(1) != 27: # Escape
    has_frame, frame = source.read()
    if not has_frame:
        break
    frame=cv2.flip(frame,1) 
    frame_gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    corners=cv2.goodFeaturesToTrack(frame_gray,maxCorners=500,qualityLevel=0.01,minDistance=15,blockSize=9)
    if corners is not None:
        for x,y in np.int32(corners).reshape(-1,2):
            cv2.circle(frame,(x,y) ,10 , (0,255,0) ,1)
    cv2.imshow(win_name, frame)
source.release()
cv2.destroyWindow(win_name)

# %%
# Out:
# 'gzip' is not recognized as an internal or external command,
# operable program or batch file.
